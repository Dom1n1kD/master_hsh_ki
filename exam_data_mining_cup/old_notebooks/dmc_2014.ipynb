# %% [markdown]
# # Exam Preparation Data Mining Cup 2014
#
# ## Files:
# - data/orders_class.txt (target features - this is the 'test' data)
# - data/orders_train.txt (training data - this is the ground truth and will be used to train the algo)
# - data/DMC 2014_realclass.txt (validation data - quality check for algo)
#
# ## File Handling:
# - Use the 'data/orders_train.txt' dataset to train the algo
# - Afterwards use 'data/orders_class.txt' dataset to predict the target feature
# - Finally check the quality of the results with 'data/DMC 2014_realclass.txt' dataset
#
# ## Scenario:
# 'On the basis of historical purchase data of an online shop a model is to be learned generating a
# prediction of the probability that a certain purchase is converted into a return on the basis of new
# purchase  data  of  the  shop.'
#
# ## Data:
# - Item kept = '0'
# - Item returned = '1'

# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import numpy as np
from datetime import timedelta
from datetime import datetime
import matplotlib.pyplot as plt

# %%
def perform_data_quality_check(initial_dataframe):
    qc_df = pd.DataFrame(columns=['field', 'missing_values', 'min_value', 'max_value'])

    for column in initial_dataframe:
        
        # calcualte the count of missing values (defined as '?' or numpy.NaN)
        if (df[column]=='?').sum() is not None or df[column].isna().sum() is not None:
            missing_values = (df[column]=='?').sum() + df[column].isna().sum()
        else:
            missing_values = float('NaN')
        
        # calculate the min and max if the field is a date or numeric
        if column not in ('size','color','salutation','state'):
            min_value = df[column].min()
            max_value = df[column].max()
        else:
            min_value = float('NaN')
            max_value = float('NaN')
    
        new_row = {'field': column, 'missing_values': missing_values, 'min_value': min_value, 'max_value': max_value}
        qc_df.loc[len(qc_df)] = new_row
        
    return qc_df

# %%
# we can maybe use parse_date as an argument to parse dates while reading the csv
#df = pd.read_csv('data/orders_train.txt', delimiter=';', parse_dates=['orderDate', 'deliveryDate', 'dateOfBirth', 'creationDate'])

df = pd.read_csv('data/orders_train.txt', delimiter=';')
df.head()
# Out:
#    orderItemID   orderDate deliveryDate  itemID size  color  manufacturerID  \
# 0            1  2012-04-01   2012-04-03     186    m  denim              25
# 1            2  2012-04-01   2012-04-03      71   9+  ocher              21
# 2            3  2012-04-01   2012-04-03      71   9+  curry              21
# 3            4  2012-04-02            ?      22    m  green              14
# 4            5  2012-04-02   1990-12-31     151   39  black              53
#
#    price  customerID salutation dateOfBirth                 state  \
# 0  69.90         794        Mrs  1965-01-06    Baden-Wuerttemberg
# 1  69.95         794        Mrs  1965-01-06    Baden-Wuerttemberg
# 2  69.95         794        Mrs  1965-01-06    Baden-Wuerttemberg
# 3  39.90         808        Mrs  1959-11-09                Saxony
# 4  29.90         825        Mrs  1964-07-11  Rhineland-Palatinate
#
#   creationDate  returnShipment
# 0   2011-04-25               0
# 1   2011-04-25               1
# 2   2011-04-25               1
# 3   2012-01-04               0
# 4   2011-02-16               0

# %%
# check for datatypes and NaN values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481092 entries, 0 to 481091
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   orderItemID     481092 non-null  int64
#  1   orderDate       481092 non-null  object
#  2   deliveryDate    481092 non-null  object
#  3   itemID          481092 non-null  int64
#  4   size            481092 non-null  object
#  5   color           481092 non-null  object
#  6   manufacturerID  481092 non-null  int64
#  7   price           481092 non-null  float64
#  8   customerID      481092 non-null  int64
#  9   salutation      481092 non-null  object
#  10  dateOfBirth     481092 non-null  object
#  11  state           481092 non-null  object
#  12  creationDate    481092 non-null  object
#  13  returnShipment  481092 non-null  int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 51.4+ MB

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)
        
display_all(df.describe(include='all').T)
# Out:
#                    count unique                     top    freq          mean  \
# orderItemID     481092.0    NaN                     NaN     NaN      240546.5
# orderDate         481092    365              2012-06-27    5577           NaN
# deliveryDate      441673    327              2013-04-04    5285           NaN
# itemID          481092.0    NaN                     NaN     NaN   1399.764779
# size              481092    122                       l   37289           NaN
# color             480949     87                   black   86252           NaN
# manufacturerID  481092.0    NaN                     NaN     NaN     29.726109
# price           481092.0    NaN                     NaN     NaN     70.440229
# customerID      481092.0    NaN                     NaN     NaN  33369.968376
# salutation        481092      5                     Mrs  461769           NaN
# dateOfBirth       432203  14308              1900-11-19    4038           NaN
# state             481092     16  North Rhine-Westphalia  111138           NaN
# creationDate      481092    775              2011-02-16  141550           NaN
# returnShipment  481092.0    NaN                     NaN     NaN      0.482425
#
#                          std  min        25%       50%        75%       max
# orderItemID     138879.44219  1.0  120273.75  240546.5  360819.25  481092.0
# orderDate                NaN  NaN        NaN       NaN        NaN       NaN
# deliveryDate             NaN  NaN        NaN       NaN        NaN       NaN
# itemID            931.075227  1.0      332.0    1569.0     2342.0    3071.0
# size                     NaN  NaN        NaN       NaN        NaN       NaN
# color                    NaN  NaN        NaN       NaN        NaN       NaN
# manufacturerID     30.064934  1.0        5.0      21.0       43.0     166.0
# price              45.502854  0.0       34.9      59.9       89.9     999.0
# customerID      23972.075259  6.0    12891.0   28426.0    51141.0   86611.0
# salutation               NaN  NaN        NaN       NaN        NaN       NaN
# dateOfBirth              NaN  NaN        NaN       NaN        NaN       NaN
# state                    NaN  NaN        NaN       NaN        NaN       NaN
# creationDate             NaN  NaN        NaN       NaN        NaN       NaN
# returnShipment      0.499692  0.0        0.0       0.0        1.0       1.0

# %%
df.boxplot(column=['dateOfBirth'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 df.boxplot(column=['dateOfBirth'])
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/plotting/_core.py:517, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     500 @Substitution(backend=_backend_doc)
#     501 @Appender(_boxplot_doc)
#     502 def boxplot_frame(
#    (...)
#     514     **kwargs,
#     515 ):
#     516     plot_backend = _get_plot_backend(backend)
# --> 517     return plot_backend.boxplot_frame(
#     518         self,
#     519         column=column,
#     520         by=by,
#     521         ax=ax,
#     522         fontsize=fontsize,
#     523         rot=rot,
#     524         grid=grid,
#     525         figsize=figsize,
#     526         layout=layout,
#     527         return_type=return_type,
#     528         **kwargs,
#     529     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/plotting/_matplotlib/boxplot.py:459, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     444 def boxplot_frame(
#     445     self,
#     446     column=None,
#    (...)
#     455     **kwds,
#     456 ):
#     457     import matplotlib.pyplot as plt
# --> 459     ax = boxplot(
#     460         self,
#     461         column=column,
#     462         by=by,
#     463         ax=ax,
#     464         fontsize=fontsize,
#     465         grid=grid,
#     466         rot=rot,
#     467         figsize=figsize,
#     468         layout=layout,
#     469         return_type=return_type,
#     470         **kwds,
#     471     )
#     472     plt.draw_if_interactive()
#     473     return ax
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/plotting/_matplotlib/boxplot.py:436, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     434     columns = data.columns
#     435 else:
# --> 436     data = data[columns]
#     438 result = plot_group(columns, data.values.T, ax, **kwds)
#     439 ax.grid(grid)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:6108, in Index._get_indexer_strict(self, key, axis_name)
#    6105 else:
#    6106     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6108 self._raise_if_missing(keyarr, indexer, axis_name)
#    6110 keyarr = self.take(indexer)
#    6111 if isinstance(key, Index):
#    6112     # GH 42790 - Preserve name from an Index
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:6168, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6166     if use_interval_msg:
#    6167         key = list(key)
# -> 6168     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6170 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6171 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['dateOfBirth'], dtype='object')] are in the [columns]"

# %% [markdown]
# ## Note
# - DataTypes are not right
#   - for example 'orderDate' is of type 'object' needs to be of type 'date'
# - 'df.info()' doesnt detect the right NaN Values because they are not numpy NaN but simple '?' instead
#   - Documentation states that there are for example missing values in column 'deliveryDate'

# %%
# perform some basic data quality checks
# including count of missing values, min and max value (if its a numeric field)
dq_check_df = perform_data_quality_check(df)
dq_check_df
# Out:
#              field  missing_values   min_value   max_value
# 0      orderItemID               0           1      481092
# 1        orderDate               0  2012-04-01  2013-03-31
# 2     deliveryDate           39419  1990-12-31           ?
# 3           itemID               0           1        3071
# 4             size               0         NaN         NaN
# 5            color             143         NaN         NaN
# 6   manufacturerID               0           1         166
# 7            price               0         0.0       999.0
# 8       customerID               0           6       86611
# 9       salutation               0         NaN         NaN
# 10     dateOfBirth           48889  1655-04-19           ?
# 11           state               0         NaN         NaN
# 12    creationDate               0  2011-02-16  2013-03-31
# 13  returnShipment               0           0           1

# %%
# replace '?' values with numpy NaN
df.replace('?', np.nan, inplace=True)

# %%
# trying to convert the Date fields to a datetime format
df[['orderDate', 'deliveryDate', 'dateOfBirth', 'creationDate']] = \
df[['orderDate', 'deliveryDate', 'dateOfBirth', 'creationDate']].apply(pd.to_datetime, format='%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In [7], line 2
#       1 # trying to convert the Date fields to a datetime format
# ----> 2 df[['orderDate', 'deliveryDate', 'dateOfBirth', 'creationDate']] = df[['orderDate', 'deliveryDate', 'dateOfBirth', 'creationDate']].apply(pd.to_datetime, format='%Y-%m-%d')
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:9558, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9547 from pandas.core.apply import frame_apply
#    9549 op = frame_apply(
#    9550     self,
#    9551     func=func,
#    (...)
#    9556     kwargs=kwargs,
#    9557 )
# -> 9558 return op.apply().__finalize__(self, method="apply")
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/apply.py:741, in FrameApply.apply(self)
#     738 elif self.raw:
#     739     return self.apply_raw()
# --> 741 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/apply.py:868, in FrameApply.apply_standard(self)
#     867 def apply_standard(self):
# --> 868     results, res_index = self.apply_series_generator()
#     870     # wrap results
#     871     return self.wrap_results(results, res_index)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/apply.py:884, in FrameApply.apply_series_generator(self)
#     881 with option_context("mode.chained_assignment", None):
#     882     for i, v in enumerate(series_gen):
#     883         # ignore SettingWithCopy here in case the user mutates
# --> 884         results[i] = self.f(v)
#     885         if isinstance(results[i], ABCSeries):
#     886             # If we have a view on v, we need to make a copy because
#     887             #  series_generator will swap out the underlying data
#     888             results[i] = results[i].copy(deep=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/apply.py:139, in Apply.__init__.<locals>.f(x)
#     138 def f(x):
# --> 139     return func(x, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1065, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1063             result = arg.tz_localize(tz)
#    1064 elif isinstance(arg, ABCSeries):
# -> 1065     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1066     if not cache_array.empty:
#    1067         result = arg.map(cache_array)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:230, in _maybe_cache(arg, format, cache, convert_listlike)
#     228 unique_dates = unique(arg)
#     229 if len(unique_dates) < len(arg):
# --> 230     cache_dates = convert_listlike(unique_dates, format)
#     231     # GH#45319
#     232     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:439, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     437 assert format is None or infer_datetime_format
#     438 utc = tz == "utc"
# --> 439 result, tz_parsed = objects_to_datetime64ns(
#     440     arg,
#     441     dayfirst=dayfirst,
#     442     yearfirst=yearfirst,
#     443     utc=utc,
#     444     errors=errors,
#     445     require_iso8601=require_iso8601,
#     446     allow_object=True,
#     447 )
#     449 if tz_parsed is not None:
#     450     # We can take a shortcut since the datetime64 numpy array
#     451     # is in UTC
#     452     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2178, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2176 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2177 try:
# -> 2178     result, tz_parsed = tslib.array_to_datetime(
#    2179         data.ravel("K"),
#    2180         errors=errors,
#    2181         utc=utc,
#    2182         dayfirst=dayfirst,
#    2183         yearfirst=yearfirst,
#    2184         require_iso8601=require_iso8601,
#    2185         allow_mixed=allow_mixed,
#    2186     )
#    2187     result = result.reshape(data.shape, order=order)
#    2188 except OverflowError as err:
#    2189     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:428, in pandas._libs.tslib.array_to_datetime()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:679, in pandas._libs.tslib.array_to_datetime()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:671, in pandas._libs.tslib.array_to_datetime()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:650, in pandas._libs.tslib.array_to_datetime()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/tslibs/np_datetime.pyx:212, in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1655-04-19 00:00:00 present at position 11578

# %%
# it is throwing an out of bounds exception because the year 1655 is not in the boundary of 'pd.to_datetime()'
min_ts = pd.Timestamp.min
max_ts = pd.Timestamp.max
print(f'min timestamp: {min_ts}, max timestamp: {max_ts}')
# Out:
# min timestamp: 1677-09-21 00:12:43.145224193, max timestamp: 2262-04-11 23:47:16.854775807

# %%
# there are a total of 3 rows which are affected by this
# it is also always the same customer ('customerID' == 48469)
df.query("dateOfBirth == '1655-04-19'")
# Out:
#         orderItemID   orderDate deliveryDate  itemID size  color  \
# 201497       201498  2012-09-12   2012-09-13    1662    l  brown
# 223802       223803  2012-09-22   2012-09-24    1662    m  brown
# 322553       322554  2013-01-08   2013-01-31    2429    M  black
#
#         manufacturerID  price  customerID salutation dateOfBirth    state  \
# 201497              36  109.9       48469        Mrs  1655-04-19  Bavaria
# 223802              36  109.9       48469        Mrs  1655-04-19  Bavaria
# 322553              11   89.9       48469        Mrs  1655-04-19  Bavaria
#
#        creationDate  returnShipment
# 201497   2011-02-16               1
# 223802   2011-02-16               1
# 322553   2011-02-16               0

# %%
# check if there are more unrealistic dates of birth
df.sort_values('dateOfBirth').head(150).to_csv('output_files/date_of_birth_analysis.csv')

# %%
age_gap = 2013 - 95
age_gap
# Out:
# 1918

# %%
# we assume that the max age of our customers are 95
# therefore we are counting rows of purchases with a birthdate older than that
len(df[(df['dateOfBirth']>='1655-01-01') & (df['dateOfBirth']<='1918-12-31')])
# Out:
# 5231

# %%
# in order to explore the 5231 rows a little further we put them into a .csv file
# and assigned them to a new dataframe
invalid_age = df[(df['dateOfBirth']>='1655-01-01') & (df['dateOfBirth']<='1918-12-31')]
invalid_age.to_csv('output_files/customer_analysis_with_invalid_date_of_birth.csv')

# %%
# now we want to check how many unique customers are affected
invalid_age['customerID'].nunique()

# display all unique customerIDs ascending
#invalid_age.sort_values('customerID')['customerID'].unique()
# Out:
# 530

# %%
# one percent of data is affected by a false birthdate
perc_of_wrong_bdate = 5231 / 481092 * 100
perc_of_wrong_bdate
# Out:
# 1.087318018175318

# %%
# check dateOfBirth is NaN
#df.loc[df['dateOfBirth'].isnull()]

# %%
# orderDate_max = 31.03.2013
# deliverDate_max = 22.07.2013
df['deliveryDate'].dropna().max()
# Out:
# '2013-07-22'

# %%
df[['orderDate', 'deliveryDate', 'dateOfBirth', 'creationDate']] = df[['orderDate', 'deliveryDate', 'dateOfBirth', 'creationDate']].apply(pd.to_datetime, format='%Y-%m-%d', errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481092 entries, 0 to 481091
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   orderItemID     481092 non-null  int64
#  1   orderDate       481092 non-null  datetime64[ns]
#  2   deliveryDate    441673 non-null  datetime64[ns]
#  3   itemID          481092 non-null  int64
#  4   size            481092 non-null  object
#  5   color           480949 non-null  object
#  6   manufacturerID  481092 non-null  int64
#  7   price           481092 non-null  float64
#  8   customerID      481092 non-null  int64
#  9   salutation      481092 non-null  object
#  10  dateOfBirth     432200 non-null  datetime64[ns]
#  11  state           481092 non-null  object
#  12  creationDate    481092 non-null  datetime64[ns]
#  13  returnShipment  481092 non-null  int64
# dtypes: datetime64[ns](4), float64(1), int64(5), object(4)
# memory usage: 51.4+ MB

# %%
dfCopy = df.copy()

dfCopy['dateOfBirth'] = pd.to_datetime(dfCopy['dateOfBirth']).dt.date  # Umwandlung in ein Datumsobjekt
dfCopy['orderDate'] = pd.to_datetime(dfCopy['orderDate']).dt.date  # Umwandlung in ein Datumsobjekt
dfCopy['Alter'] = (pd.to_datetime(dfCopy['orderDate']) - pd.to_datetime(dfCopy['dateOfBirth'])).apply(lambda x: x.days // 365) # Lambda Funktion um es auf den Tag genau zu berechnen.

#Ungenauere Alternative, beinhaltet Tage nicht
#dfCopy['Alter'] = (dfCopy['orderDate'].dt.year - dfCopy['dateOfBirth'].dt.year)

# Überprüfen des aktualisierten DataFrames
print(dfCopy.head())
